# %% [markdown]
# # Identification
# Please indicate your name
#
# Student 1: Yalda Eftekhari
#
# Student 2: Defne Gulmez

# %% [markdown]
# # Practical work 7: Split and Merge
#
# In this practical work, we implement and test the split and merge algorithm.

# %%
### Usefull libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

### Data
img_test = np.full((64,64),150,dtype=np.uint8)
img_test[32:48,16:16+32] = 100
img_test[8:24,40:56] = 50
angio = np.array(Image.open('img/angiogra.png'))
cam = np.array(Image.open('img/cameraman.png'))
muscle = np.array(Image.open('img/muscle.png'))
prisme = np.array(Image.open('img/prisme.png'))
seiche = np.array(Image.open('img/seiche.png'))

### Usefull functions
def neighbors(b,K):
    """ blockStat*list[blockStat]->list[blockStat]
        returns the list of neighbors of b and elements of K 
    """
    def belongsTo(x,y,a):
        """ int*int*BlockStat -> bool 
            Test if pixel (x,y) belongs to block a 
        """
        return x>=a[0] and y>=a[1] and x<a[0]+a[2] and y<a[1]+a[3]
    def areNeighbors(a,b):
        """ BlockStat**2 -> bool
            Test if a and b are neighbors
        """
        if a[2]>b[2] and a[3]>b[3]:
            a,b=b,a
        x,y = a[0]+a[2]//2,a[1]+a[3]//2
        return belongsTo(x+a[2],y,b) or belongsTo(x-a[2],y,b) or belongsTo(x,y+a[3],b) or belongsTo(x,y-a[3],b)
    return [n for n in K if areNeighbors(b,n)]

# %% [markdown]
# ## Exercise 1
#
# ### Question 1
# Write the recursive function ``split()`` discussed in tutorial work.
# It takes as input the image, a region, a predicate, and a variable number of arguments.
# The region is a Python formal type ``Block`` defined by:
# ```python
# type Block = tuple[int**4]
# ```
# The function ``split()`` returns a quadtree, a Python formal type, recursivelly defined by:
# ```python
# type QuadTree = list[(QuadTree**4|Block)]
# ```
#
# The predicate is a Python function with the following signature:
# ```python
# Array*Block*...->bool
# ```
# It can take a variable number of parameters which correspond to the parameters required by the predicate.

# %%
# type Block = tuple[int**4]
# type QuadTree = list[(QuadTree**4|Block)] 

def split(I,reg,pred,*args):
    """ Array*Block*(Array*Block*...->bool)*... -> 4-aire
        Performs a quadtree splitting of image I drived by a predicate
    """
    x,y,n,m = reg
    if pred(I, reg, *args) and m > 2 and n > 2:
        m2 = m // 2
        n2 = n // 2
        nw = split(I, (x,y,n2,m2), pred, *args)
        ne = split(I, (x,y+m2,n2,m2), pred, *args)
        sw = split(I, (x+n2,y,n2,m2), pred, *args)
        se = split(I, (x+n2,y+m2,n2,m2), pred, *args)
        return [nw, ne, sw, se]
    return [reg]

# %% [markdown]
# ### Question 2
# Write the function ```predsplit(I,B,*args)``` with signature:
# ```python
# Array*Block*... -> bool
# ```
# that returns True if the standard deviation of image ``I`` computed in region ``B`` is greater than the first value of argument ``*args`` (it can be accessed simply by ``*args[0]``).

# %%
def predsplit(I,reg,*args):
    """ Array*Block*... -> bool
    """ 
    res = np.std(I[reg[0]:reg[0]+reg[2], reg[1]:reg[1]+reg[3]]) > args[0]
    return res

# %% [markdown]
# ### Question 3
# Write the function ``listRegions()`` which applies a depth-first search on the quadtree given as parameter, and returns the list of the leaves of the quadtree.
#
# Some recalls about lists in Python;
#  - Initialization: `L = []` (empty list)
#  - Add a element `a` into a list `L`: `L.append(a)`

# %%
def listRegions(L):
    """ QuadTree -> list[Block]
    """
    regions = []  # Initialize a list to store the leaf blocks
    
    if len(L) == 1 and isinstance(L[0], tuple):  # leaf node
        regions.append(L[0])
    else: 
        regions.extend(listRegions(L[0]))
        regions.extend(listRegions(L[1]))
        regions.extend(listRegions(L[2]))
        regions.extend(listRegions(L[3]))
    
    return regions

# %% [markdown]
# ### Question 4
# Test your codes on the synthetic image ``img_test`` seen in tutorial work. Print the value returned by ``split()`` as well as the one returned by ``listRegions()``.

# %%
reg = (0,0,img_test.shape[0], img_test.shape[1])
L = listRegions(split(img_test, reg , predsplit, 6))

# Unit test: L is the quadtree produced from img_test
assert len(L) == 25
print("OK")
print("splitting result:", split(img_test, reg , predsplit, 6))
print("listRegions() result:", L)
# Out:
# OK
# splitting result: [[(0, 0, 32, 32)], [[[(0, 32, 8, 8)], [(0, 40, 8, 8)], [(8, 32, 8, 8)], [(8, 40, 8, 8)]], [[(0, 48, 8, 8)], [(0, 56, 8, 8)], [(8, 48, 8, 8)], [(8, 56, 8, 8)]], [[(16, 32, 8, 8)], [(16, 40, 8, 8)], [(24, 32, 8, 8)], [(24, 40, 8, 8)]], [[(16, 48, 8, 8)], [(16, 56, 8, 8)], [(24, 48, 8, 8)], [(24, 56, 8, 8)]]], [[(32, 0, 16, 16)], [(32, 16, 16, 16)], [(48, 0, 16, 16)], [(48, 16, 16, 16)]], [[(32, 32, 16, 16)], [(32, 48, 16, 16)], [(48, 32, 16, 16)], [(48, 48, 16, 16)]]]
# listRegions() result: [(0, 0, 32, 32), (0, 32, 8, 8), (0, 40, 8, 8), (8, 32, 8, 8), (8, 40, 8, 8), (0, 48, 8, 8), (0, 56, 8, 8), (8, 48, 8, 8), (8, 56, 8, 8), (16, 32, 8, 8), (16, 40, 8, 8), (24, 32, 8, 8), (24, 40, 8, 8), (16, 48, 8, 8), (16, 56, 8, 8), (24, 48, 8, 8), (24, 56, 8, 8), (32, 0, 16, 16), (32, 16, 16, 16), (48, 0, 16, 16), (48, 16, 16, 16), (32, 32, 16, 16), (32, 48, 16, 16), (48, 32, 16, 16), (48, 48, 16, 16)]

# %% [markdown]
# ### Question 5
# Write the function ```drawRegions(L,I)``` which takes as arguments a list of regions, an image, and returns an image  where the boundaries of each region have been traced with red color. Indication: the returned image is a hypermatrix of dimension 3, the third dimension is of size 3 and encodes the red, green and blue components of a RGB colorspace. Test the function on the previous example.

# %%
def drawRegions(L,I):
    """ list[Block]*Array -> Array
        parcours de la liste dessin des régions 
    """
    # Make a copy of the image to avoid modifying the original
    if len(I.shape) == 2:
        img_with_boundaries = np.stack((I,)*3, axis=-1)
    else:
        img_with_boundaries = np.copy(I)
    
    # Define the red color in RGB
    red = [255, 0, 0]
    
    # Iterate through each region in the list L
    for (x, y, n, m) in L:
        # Top boundary
        img_with_boundaries[x, y:y+m, :] = red
        # Bottom boundary
        img_with_boundaries[x+n-1, y:y+m, :] = red
        # Left boundary
        img_with_boundaries[x:x+n, y, :] = red
        # Right boundary
        img_with_boundaries[x:x+n, y+m-1, :] = red
    
    return img_with_boundaries


plt.imshow(drawRegions(L, img_test))
plt.show()

# %% [markdown]
# ### Question 6
# Add a Gaussian noise with standard deviation 5 to the image ``img_test``.
# Apply the quadtree splitting on the noisy image by adjusting the threshold to obtain the same result as in the previous question.
# Which threshold value should be chosen? Does this make sense to you?
#
# Hint: use the Numpy function ``random.randn()`` which generates random values according to a normal distribution (Gaussian distribution of null mean and variance 1). To obtain realizations of a Gaussian distribution of standard deviation $\sigma$, it is sufficient to multiply by $\sigma$ the realizations of a normal distribution.

# %%
from numpy import random

# Generate noise and add to img_test to create a noisy image
noise = np.random.randn(64, 64) * 5 #make the sd 5
noise_img_test = img_test + noise.astype(int)

reg = (0, 0, noise_img_test.shape[0], noise_img_test.shape[1])
L = listRegions(split(noise_img_test, reg, predsplit, 6))

# Display the noisy image and the image with regions side by side
fig, axs = plt.subplots(1, 2, figsize=(10, 6))

# Show the noisy image in the first subplot
axs[0].imshow(noise_img_test, cmap='gray')
axs[0].set_title("Noisy Image")
axs[0].axis('off')  # Hide axes

# Show the noisy image with regions in the second subplot
axs[1].imshow(drawRegions(L, noise_img_test))
axs[1].set_title("Noisy Image with Regions")
axs[1].axis('off')  # Hide axes
plt.show()

threshold = [1, 2, 3, 4, 5, 6, 7, 8]

fig, axs = plt.subplots(2, 4, figsize=(16, 8))
axs = axs.flatten()

for i, t in enumerate(threshold):
    reg = (0, 0, noise_img_test.shape[0], noise_img_test.shape[1])
    L = listRegions(split(noise_img_test, reg, predsplit, t))
    axs[i].imshow(drawRegions(L, noise_img_test))
    axs[i].set_title(f"Threshold = {t}")
    axs[i].axis('off')

# Display the images side by side
plt.tight_layout()
plt.show()
'''We observe that in both img_test and the noisy version of img_test, the appropriate threshold value to achieve the same splitting is 6.
Technically, it might be expected for the threshold to increase when noise is added, due to the resulting higher variation in pixel values. 
However, in img_test, the regions are simple and uniform (flat areas of constant intensities). As a result, the added noise is not enough
to significantly alter the statistical properties of the original image.'''
# Out:
# 'We observe that in both img_test and the noisy version of img_test, the appropriate threshold value to achieve the same splitting is 6.\nTechnically, it might be expected for the threshold to increase when noise is added, due to the resulting higher variation in pixel values. \nHowever, in img_test, the regions are simple and uniform (flat areas of constant intensities). As a result, the added noise is not enough\nto significantly alter the statistical properties of the original image.'

# %% [markdown]
# ## Exercise 2
#
# Experiment the split algorithm on the 4 natural images provided. For each image try to find the threshold that seems to you visually the best. Display the number of regions obtained after splitting.

# %%
angio = np.array(Image.open('img/angiogra.png')) #13
cam = np.array(Image.open('img/cameraman.png')) # 20
muscle = np.array(Image.open('img/muscle.png')) # 20
prisme = np.array(Image.open('img/prisme.png')) # 15 
seiche = np.array(Image.open('img/seiche.png'))  # 10

image_list = [angio, cam, muscle, prisme, seiche]
threshold = list(range(2, 33, 1))

for img in image_list:
    plt.imshow(img)
    plt.show()

    # Create a 2x6 grid (since we have 12 thresholds)
    fig, axs = plt.subplots(4, 8, figsize=(18, 8))
    axs = axs.flatten()  # Flatten the 2D grid into a 1D array for easier indexing

    for i, t in enumerate(threshold):
        reg = (0, 0, img.shape[0], img.shape[1])
        L = listRegions(split(img, reg, predsplit, t))
        axs[i].imshow(drawRegions(L, img))
        axs[i].set_title(f"Threshold = {t}")
        axs[i].axis('off')  # Remove axis for cleaner images

    # Adjust the layout for better spacing between images
    plt.tight_layout()
    plt.show()

img = muscle
reg = (0, 0, img.shape[0], img.shape[1])
L = listRegions(split(img, reg, predsplit, 10))

'''The chosen thresholds are 13 for angio, 20 for cam, 20 for muscle, 15 for prisme, and 10 for seiche.'''
# Out:
# 'The chosen thresholds are 13 for angio, 20 for cam, 20 for muscle, 15 for prisme, and 10 for seiche.'

# %% [markdown]
# ## Exercise 3
# ### Question 1
# Modify the function ``listRegions(L)`` to make it a function ``listRegionsStat(L,I)`` which computes the list of leaves of the quadtree ``L``. Each element of this list will be enriched with three scalar values: the first being the size, the second the mean and the third the variance of pixel values of the block in the image ``I``. This function then returns a list whose elements have the following formal type:
# ```python
# type BlockStat = tuple[int**4,int,float**2]
# ```
#
# The first four values are those of the ``Block`` type, the fifth is the size of the block (in number of pixels) and the last two values are the mean and variance calculated over the region.

# %%
#type BlockStat = tuple[int**4,int,float**2]

def listRegionsStat(L, I):
    """ QuadTree*Array -> list[BlockStat] """
    regions_stat = []  # Initialize a list to store the new block + its stats
    if len(L) == 1 and isinstance(L[0], tuple):  # leaf_node
        x, y, n, m = L[0]  # block details
        block = I[x:x+n, y:y+m]  # Extract the corresponding region in the image
        size = n * m  # new size
        mean = np.mean(block)  # new mean
        varience = np.var(block)  # new variance
        regions_stat.append((x, y, n, m, size, mean, varience))  # make the new block by adding the stats
    else:  
        regions_stat.extend(listRegionsStat(L[0], I))
        regions_stat.extend(listRegionsStat(L[1], I))
        regions_stat.extend(listRegionsStat(L[2], I))
        regions_stat.extend(listRegionsStat(L[3], I))

    return regions_stat

# %% [markdown]
# ### Question 2
# In the remainder, the formal type is considered:
# ```python
# type Region = list[BlocStats]
# ```
# A region, as seen during the tutorial work, is therefore a list of blocks. Write the predicate ``predmerge(b,R,*args)`` as seen in tutorial work. This function returns ``True`` if the ``b`` block should merge into the ``R`` region. If a merge happens, then the first item of ``R`` will have its statistics updated to describe the statistics of the region ``R`` merged with `b`.

# %%
def predmerge(b,R,*args):
    """ BlocsStat*Region*... -> bool 
        If merge, R[0] is modified
    """
    #if R does not exist automatically return R
    if not R:
        return False

    #extract the stats for b and R
    x_b, y_b, n_b, m_b, size_b, mean_b, var_b = b
    x_R, y_R, n_R, m_R, size_R, mean_R, var_R = R[0]

    #define the new regions for the merged version
    #NOTE: left top corner in an image is (0,0)
    new_x = min(x_b, x_R) # the x coordinate on the most left
    new_y = min(y_b, y_R) # the y coordinate on the most top
    new_n = max(x_b + n_b, x_R + n_R) - new_x  # New height
    new_m = max(y_b + m_b, y_R + m_R) - new_y  # New width

    new_size = size_R + size_b
    new_mean = (mean_R * size_R + mean_b * size_b) / new_size
    new_var = (
        (size_R * (var_R + (mean_R - new_mean) ** 2)) +
        (size_b * (var_b + (mean_b - new_mean) ** 2))
    ) / new_size
    
    # Check variance threshold
    var_threshold = args[0]
    if new_var <= var_threshold:
        # Update the first block in R with the new merged statistics
        R[0] = (new_x, new_y, new_n, new_m, new_size, new_mean, new_var)
        return True
    return False

# %% [markdown]
# ### Question 3
# Using `predmerge()` and `neighbors()` functions, given at the beginning of the notebook, write the function ``merge()`` discussed in tutorial work (exercise 7.6).
#
# Recalls on Python lists:
# - Remove an element `a` from a list `L`: `L.remove(a)`
# - Test if `a` belongs to a list `L`: `a in L`
# - Iterate the elements of a list `L`: `for a in L:`
# - Access to an element of a list: as with numpy arrays

# %%
def merge(S,I,pred,*args):
    """ QuadTree*Array*(BlockStat*Region*...->bool) -> list[Region]
        Merge the leaves of S in a list of regions
    """

    merged_region = []  # Initialize the list of merged regions

    while S:
        b = S.pop(0)  # Remove the first block
        region = [b]  # Start a new region with block `b`

        neighbors_check = neighbors(b, S)  # Find neighbors of `b`
        while neighbors_check: 
            n = neighbors_check.pop(0)  # Get the first neighbor
            if n in S and pred(n, region, *args):  # Check if `n` can merge
                S.remove(n)  # Remove that neighbor
                neighbors_check.extend(
                    [nb for nb in neighbors(n, S) if nb not in neighbors_check]
                )
        # Completed region
        merged_region.append(region)

    return merged_region

# %% [markdown]
# ### Question 4
# Test the previous functions using the synthetic image `img_test`. In particular, check that merge() returns a list of 3 elements (i.e. 3 regions).

# %%
# region def + split the image 
reg = (0, 0, img_test.shape[0], img_test.shape[1])
L = split(img_test, reg, predsplit, 6)

blocks_stat = listRegionsStat(L, img_test)
#for debugging:
print(f"# of blocks before merging: {len(blocks_stat)}")

# merging
M = merge(blocks_stat, img_test, predmerge, 30)  # Adjust threshold if needed

# Debugging:
print(f"# of merged regions: {len(M)}")
for i, region in enumerate(M):
    print(f"Region {i + 1}:")
    for block in region:
        print(block)

# Unit test: M is the list of merged blocs returned by merge()
assert len(M) == 3
print("OK")
# Out:
# # of blocks before merging: 25
# # of merged regions: 3
# Region 1:
# (0, 0, 64, 64, 3328, 150.0, 0.0)
# Region 2:
# (8, 40, 16, 16, 256, 50.0, 0.0)
# Region 3:
# (32, 16, 16, 32, 512, 100.0, 0.0)
# OK

# %% [markdown]
# ### Question 5
# Write a function ``regions(LR,shape)`` that takes as arguments a list of regions (such as returned by the function ``merge()``) and an image size, and returns an image of the regions. Each region will be colored with the gray level corresponding to the average of the region. You also can assign random colors to each region to clearly distinguish adjacent regions. The ``shape`` parameter gives the size of the image to be reconstructed.
#
# Test the function on the previous example.

# %%
def regions(LR,shape):
    """ list[Region]*tuple[int,int] -> Array """
    new_image = np.zeros(shape, dtype=np.uint8) 

    for reg in LR:
        for block in reg:
            x, y, n, m, size, mean, var = block  
            # Fill the corresponding region with the gray level based on mean
            new_image[x:x+n, y:y+m] = int(mean)  

    return new_image
test_img_regions = regions(M, img_test.shape)
plt.imshow(test_img_regions, cmap='gray')
plt.title("Reconstructed Regions")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Exercise 4: experiments
# ### Question 1
# Test the function ``merge()`` on the images ``angio``, ``cam``, ``muscle``, ``prisme`` and ``seiche``. Try to produce the best segmentations.

# %%
#splitting thresholds for each image found in the above question
splitting_thresholds = {
    "angio": 13,
    "cam":20,
    "muscle": 20,
    "prisme": 15,
    "seiche": 10,
}

images = {
    "angio": angio,
    "cam": cam,
    "muscle": muscle,
    "prisme": prisme,
    "seiche": seiche
}

# %%
#A function to test the code on each image based on the splitting thresholds defined above and a variety of merging thresholds
def test_merge_on_images(images, variance_thresholds):
    for img_name, img in images.items():
        print(f"Testing on image: {img_name}") #for debugging
        
        #split based on tresholds defined above
        split_threshold = splitting_thresholds[img_name] 
        reg = (0, 0, img.shape[0], img.shape[1])
        split_res = split(img, reg, predsplit, split_threshold)  

        #list the regions along with its stats
        blocks_stat = listRegionsStat(split_res, img) 

        # for side by side comp, otherwise it is hard to see
        cols = min(len(variance_thresholds), 5)  # Number of images per row
        rows = (len(variance_thresholds) + cols - 1) // cols
        fig, axs = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
        axs = axs.flatten()
        fig.suptitle(f"{img_name} - Segmentations by Threshold", fontsize=16)
        
        for i, threshold in enumerate(variance_thresholds):
            # Merge using the merging threshold
            merged_regions = merge(blocks_stat.copy(), img, predmerge, threshold)

            # Reconstruct image from merged regions
            reconstructed_image = regions(merged_regions, img.shape)

            axs[i].imshow(reconstructed_image, cmap='gray')
            axs[i].set_title(f"Threshold: {threshold}")
            axs[i].axis('off')

        for j in range(len(variance_thresholds), len(axs)):
            axs[j].axis('off')

        plt.tight_layout()
        plt.show()

# variance thresholds 3 --> 40 3 by 3
variance_thresholds = list(range(3, 41, 3))

#Run the whole code
test_merge_on_images(images, variance_thresholds)

# We have adjusted these thresholds to see which one would be better for each image and we think the best thresholds are as follows:
#angio --> 15
#cam --> < 3
#musle --> 24
#prisme --> 15
#seiche --> 12

#However it should be noted that catching the small details is quite hard, considering the blurry nature of the images, and therefore these 
#thresholds might not be optimal but it is close to the optimal.
# Out:
# Testing on image: angio
# Testing on image: cam
# Testing on image: muscle
# Testing on image: prisme
# Testing on image: seiche

# %% [markdown]
# ### Question 2
# The result of the merge algorithm highly depends on how you visit the regions. One can then sort the leaves of the quadtree, for example, from the smallest to the largest blocks, or the opposite (use the Python function ``sorted()``).
# The same question arises when calculating the set of neighbors of the merged region. Should they be sorted? If yes, according to which criteria? their size? their proximity?
# Obviously there is no universal answer but it should be adapted to each type of problem.
# Do some tests to see the influence of these sortings on the result of the merger.

# %%
merging_thresholds = {
    "angio": 15,
    "cam": 3,
    "muscle": 24,
    "prisme": 15,
    "seiche": 12,
}

# %%
# Sorting functions

#by size
def sort_by_size(block):
    return block[4]  

#by proximity -used in sorting neighbors
def sort_by_proximity(block, reference_block):
    x1, y1, _, _ = block[:4]
    x_ref, y_ref, _, _ = reference_block[:4]
    return (x1 - x_ref)**2 + (y1 - y_ref)**2

#sort by mean
def sort_by_mean_intensity(block):
    return block[5]

#sort by variance
def sort_by_variance(block):
    return block[6]

# Merge Function with Sorting
def merge_with_sorting(S, I, pred, sort_leaves=None, sort_neighbors=None, merge_threshold=None):
    merged_region = []

    # Sort leaves
    if sort_leaves:
        S = sorted(S, key=sort_leaves)

    while S:
        b = S.pop(0)  # Remove the first block
        region = [b]  # Start a new region with block b

        # Find neighbors
        neighbors_to_check = neighbors(b, S)

        # Sort neighbors
        if sort_neighbors: 
            if sort_neighbors == sort_by_proximity:
                neighbors_to_check = sorted(neighbors_to_check, key=lambda n: sort_neighbors(n, b))
            else:
                neighbors_to_check = sorted(neighbors_to_check, key=sort_neighbors)

        while neighbors_to_check:
            n = neighbors_to_check.pop(0)  # Get the first neighbor
            if n in S and pred(n, region, merge_threshold): 
                S.remove(n)
                neighbors_to_check.extend(
                    [nb for nb in neighbors(n, S) if nb not in neighbors_to_check]
                )

        merged_region.append(region)

    return merged_region

# sorting options
sorting_options = {
    "No Sorting": (None, None),
    "Leaves: Size": (sort_by_size, None),
    "Leaves: Mean Intensity": (sort_by_mean_intensity, None),
    "Leaves: Variance": (sort_by_variance, None),
    "Neighbors: Proximity": (None, sort_by_proximity),
    "Neighbors: Size": (None, sort_by_size),
    "Leaves: Size, Neighbors: Proximity": (sort_by_size, sort_by_proximity),
    "Leaves: Mean Intensity, Neighbors: Proximity": (sort_by_mean_intensity, sort_by_proximity),
    "Leaves: Variance, Neighbors: Proximity": (sort_by_variance, sort_by_proximity),
    "Leaves: Variance, Neighbors: Size": (sort_by_variance, sort_by_size)
}

#tresholds as found to be the best in above questions
split_threshold = 20
merge_threshold = 3
reg = (0, 0, cam.shape[0], cam.shape[1])


split_res = split(cam, reg, predsplit, split_threshold)
blocks_stat = listRegionsStat(split_res, cam)

num_sorting_options = len(sorting_options)
rows = (num_sorting_options + 1) // 2  #  2 images per row
fig, axs = plt.subplots(rows, 2, figsize=(10, 5 * rows)) 
fig.suptitle("Sorting Comparisons for Image 'cam'", fontsize=16)


axs = axs.flatten()

for ax, (sort_name, (sort_leaves, sort_neighbors)) in zip(axs, sorting_options.items()):
    merged_regions = merge_with_sorting(
        blocks_stat.copy(), cam, predmerge,
        sort_leaves=sort_leaves,
        sort_neighbors=sort_neighbors,
        merge_threshold=merge_threshold 
    )

    # Reconstruct the image
    reconstructed_image = regions(merged_regions, cam.shape)

    # Display
    ax.imshow(reconstructed_image, cmap='gray')
    ax.set_title(sort_name)
    ax.axis('off')

for i in range(len(sorting_options), len(axs)):
    axs[i].axis('off')

plt.tight_layout()
plt.show()
'''
After debugging, we primarily focused on the image cam as it is the clearest image, making it much easier for the human eye to determine 
which version of sorting is the best. We observed that sorting the leaves by mean intensity or variance produced the best results compared 
to no sorting or sorting by size. Additionally, sorting the neighbors by proximity or size did not significantly affect the outcome. 
We also tested some combined sorting strategies and found that sorting the leaves by variance or mean can compensate for errors caused by 
neighbor sorting. Overall, we recommend sorting only the leaves by mean intensity or variance."
'''
# Out:
# '\nAfter debugging, we primarily focused on the image cam as it is the clearest image, making it much easier for the human eye to determine \nwhich version of sorting is the best. We observed that sorting the leaves by mean intensity or variance produced the best results compared \nto no sorting or sorting by size. Additionally, sorting the neighbors by proximity or size did not significantly affect the outcome. \nWe also tested some combined sorting strategies and found that sorting the leaves by variance or mean can compensate for errors caused by \nneighbor sorting. Overall, we recommend sorting only the leaves by mean intensity or variance."\n'

# %% [markdown]
# ### Question 3
# Imagine and experiment alternative predicates for both the split and the merge steps. It is possible to use edges-based predicates, and also to combine with variance-based predicates.

# %%
from scipy.ndimage import sobel

#PREDS FOR SPLIT
#edge based pred
def edge_based_predicate(I, reg, threshold):

    x, y, n, m = reg
    region = I[x:x+n, y:y+m]

    # Compute edge magnitude
    edge_x = sobel(region, axis=0)
    edge_y = sobel(region, axis=1)
    edge_magnitude = np.sqrt(edge_x**2 + edge_y**2)

    # Split if the mean edge magnitude is bigger than the threshold
    return edge_magnitude.mean() > threshold


#var + edge based combined Pred
def combined_predicate(I, reg, variance_threshold, edge_threshold):
    x, y, n, m = reg
    region = I[x:x+n, y:y+m]

    # Variance-based condition
    variance_condition = np.var(region) > variance_threshold

    # Edge-based condition
    edge_x = sobel(region, axis=0)
    edge_y = sobel(region, axis=1)
    edge_magnitude = np.sqrt(edge_x**2 + edge_y**2)
    edge_condition = edge_magnitude.mean() > edge_threshold

    # Combine conditions
    return variance_condition or edge_condition

# %%
#  Using combined predicate + img cam
quadtree_combined = split(cam, reg, combined_predicate, 35, 12)

# Visualize results
blocks_stat_combined = listRegionsStat(quadtree_combined, cam)
merged_regions_combined = merge(blocks_stat_combined, cam, predmerge, 3) 
reconstructed_combined = regions(merged_regions_combined, cam.shape)

plt.imshow(reconstructed_combined, cmap='gray')
plt.title("Combined Predicate Segmentation")
plt.show()

''' After testing out multiple options we saw that the best combination from the list of combinations below was variance = 35, edge=12. 
and even that was not a great fix. It might be possible to conclude that this combined pred is not the most optimal prediction method.
# Parameter combinations for testing
parameter_combinations = [
    (10, 3),
    (15, 4),
    (20, 5),
    (25, 8),
    (30, 10),
    (35, 12),
    (40, 15),
    (45, 18),
    (50, 20),
    (50, 3),
    (50, 8),
    (50, 12),   
]
'''
'''Note: we did not include the whole code into here that runs all of these parameters because it takes very long to run.'''
# Out:
# 'Note: we did not include the whole code into here that runs all of these parameters because it takes very long to run.'

# %%
#  Using edge pred + img cam
quadtree_combined = split(cam, reg, edge_based_predicate, 6)

blocks_stat_combined = listRegionsStat(quadtree_combined, cam)
merged_regions_combined = merge(blocks_stat_combined, cam, predmerge, 3)
reconstructed_combined = regions(merged_regions_combined, cam.shape)

plt.imshow(reconstructed_combined, cmap='gray')
plt.title("Edge Predicate Segmentation")
plt.show()

''' After testing out multiple options we saw that the best combination from the list of combinations below was edge=6. 
and even that was not a great fix. It might be possible to conclude that this edge pred is not the most optimal prediction method.
# Parameter combinations for testing
# options for treshold
parameter_combinations = [1, 2, 3, 4, 5, 6, 7, 8, 9]
'''
'''Note: we did not include the whole code into here that runs all of these parameters because it takes very long to run.'''
# Out:
# 'Note: we did not include the whole code into here that runs all of these parameters because it takes very long to run.'

# %%
#PRED FOR Merge
#pred based on edge
#using the bult-in sobel module
from scipy.ndimage import sobel

def edge_based_merge(b, R, edge_threshold, I):
    if not R:
        return False

    # Extract stats for block b
    x_b, y_b, n_b, m_b, size_b, mean_b, var_b = b

    # Extract stats for the first block in the region
    x_R, y_R, n_R, m_R, size_R, mean_R, var_R = R[0]

    # Calculate edge magnitude for both blocks using Sobel
    edges_b = sobel(I[y_b:y_b + n_b, x_b:x_b + m_b])
    edges_R = sobel(I[y_R:y_R + n_R, x_R:x_R + m_R])

    # Compute mean edge magnitudes
    mean_edge_b = np.mean(edges_b)
    mean_edge_R = np.mean(edges_R)

    # Merge if edge magnitude difference is below the threshold
    return abs(mean_edge_b - mean_edge_R) < edge_threshold

#combined pred of edge + var
def combined_merge(b, R, variance_threshold, edge_threshold, I):
    if not R:
        return False

    # Extract stats for b and the first block in R
    x_b, y_b, n_b, m_b, size_b, mean_b, var_b = b
    x_R, y_R, n_R, m_R, size_R, mean_R, var_R = R[0]

    # Variance-based condition
    var_condition = abs(var_b - var_R) < variance_threshold

    # Edge-based condition
    edges_b = sobel(I[x_b:x_b + n_b, y_b:y_b + m_b])
    edges_R = sobel(I[x_R:x_R + n_R, y_R:y_R + m_R])
    mean_edge_b = np.mean(edges_b)
    mean_edge_R = np.mean(edges_R)
    edge_condition = abs(mean_edge_b - mean_edge_R) < edge_threshold

    # Merge if all conditions are satisfied
    return var_condition and edge_condition

# %%
reg = (0, 0, cam.shape[0], cam.shape[1])
quadtree = split(cam, reg, predsplit, 6)
blocks_stat = listRegionsStat(quadtree, cam)

#new tresholds for pred
variance_threshold = 2
edge_threshold = 2

merged_regions = merge(blocks_stat, cam, combined_merge, variance_threshold, edge_threshold, cam)
reconstructed_image = regions(merged_regions, cam.shape)

plt.imshow(reconstructed_image, cmap='gray')
plt.title("Segmented Image with Combined Merge Predicate")
plt.show()
''' After testing out multiple options we saw that the best combination from the list of combinations below was variance = 2, edge=2. 
and even that was not a great fix. It might be possible to conclude that this combined pred is not the most optimal prediction method.
# Parameter combinations for testing
parameter_combinations = [
    (2,2),
    (2, 4),
    (2,6),
    (2, 8),
    (3, 9),
    (4, 10),
    (6, 12),
    (9, 15),
    (15, 10),
    (20, 12),
    (25, 15),
    (30, 20),
    (35, 25),
    (40, 30),
    (45, 35),
    (50, 40),
    (55, 45),
    (60, 50),
    (65, 55),
    (70, 60),
]
'''
'''Note: we did not include the whole code into here that runs all of these parameters because it takes very long to run.'''
# Out:
# 'Note: we did not include the whole code into here that runs all of these parameters because it takes very long to run.'

# %%
# Define the region and generate the quadtree
reg = (0, 0, cam.shape[0], cam.shape[1])
quadtree = split(cam, reg, predsplit, 6)
blocks_stat = listRegionsStat(quadtree, cam)

# Define the threshold for edge-based merging
edge_threshold = 1

# Perform the merging using the edge-based merge predicate
merged_regions = merge(blocks_stat, cam, edge_based_merge, edge_threshold, cam)

# Reconstruct the image from the merged regions
reconstructed_image = regions(merged_regions, cam.shape)

# Visualize the result
plt.imshow(reconstructed_image, cmap='gray')
plt.title("Segmented Image with Edge-Based Merge Predicate")
plt.show()

''' After testing out multiple options we saw that the best combination from the list of combinations below was edge=1. 
and even that was not a great fix. It might be possible to conclude that this edge pred is not the most optimal prediction method.
# Parameter combinations for testing
# options for treshold
parameter_combinations = [1, 2, 3, 4, 5, 6, 7, 8, 9]
'''
'''Note: we did not include the whole code into here that runs all of these parameters because it takes very long to run.'''
# Out:
# 'Note: we did not include the whole code into here that runs all of these parameters because it takes very long to run.'
